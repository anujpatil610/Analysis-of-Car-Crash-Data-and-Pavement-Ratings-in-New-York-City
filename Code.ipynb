# %%
import pandas as pd

# Load the two datasets
car_crashes = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
pavement_quality = pd.read_csv('Street_Pavement_Rating.csv')

# Get the number of rows and columns in each dataset before merging
car_crashes_rows, car_crashes_cols = car_crashes.shape
pavement_quality_rows, pavement_quality_cols = pavement_quality.shape

# Merge the two datasets
with open('merged_car_crash_pavement_data.csv', encoding='utf-8', errors='replace') as file:
    merged_data = pd.read_csv(file)

# Get the number of rows and columns in the merged dataset
merged_rows, merged_cols = merged_data.shape

# Print the results as a table
print("| Dataset | Rows Before Merging | Rows After Merging | Columns |\n"
      "|---------|--------------------|--------------------|---------|\n"
      f"| Car Crashes | {car_crashes_rows} | - | {car_crashes_cols} |\n"
      f"| Pavement Quality | {pavement_quality_rows} | - | {pavement_quality_cols} |\n"
      f"| Merged Data | - | {merged_rows} | {merged_cols} |\n")
# Out:
# | Dataset | Rows Before Merging | Rows After Merging | Columns |
# |---------|--------------------|--------------------|---------|
# | Car Crashes | 1048575 | - | 29 |
# | Pavement Quality | 133553 | - | 12 |
# | Merged Data | - | 1048575 | 26 |

# %%
import numpy as np

# Function to check if a value is NaN, null or 0
def is_not_null_nor_zero(value):
    return not pd.isnull(value) and value != 0

# Get a sample of 3 unique rows from the merged dataset
sample_data = merged_data.sample(3)

# Print the header and the sample data as a table
header = sample_data.columns
print("|", "|".join([f" {col} " for col in header]), "|")
print("|", "|".join(["-" * (len(col) + 2) for col in header]), "|")

for index, row in sample_data.iterrows():
    filtered_row = [value if is_not_null_nor_zero(value) else " " for value in row]
    print("|", "|".join([f" {str(value)} " for value in filtered_row]), "|")
# Out:
# |  CRASH DATE | CRASH TIME | BOROUGH | ZIP CODE | LATITUDE | LONGITUDE | ON STREET NAME | CROSS STREET NAME | OFF STREET NAME | NUMBER OF PERSONS INJURED | NUMBER OF PERSONS KILLED | NUMBER OF PEDESTRIANS INJURED | NUMBER OF PEDESTRIANS KILLED | NUMBER OF CYCLIST INJURED | NUMBER OF CYCLIST KILLED | NUMBER OF MOTORIST INJURED | NUMBER OF MOTORIST KILLED | CONTRIBUTING FACTOR VEHICLE 1 | VEHICLE TYPE CODE 1 | COLLISION_ID | Pavement_LATITUDE | Pavement_LONGITUDE | Pavement_SegmentID | Pavement_ManualRati | Pavement_RatingLaye | Pavement_Inspection  |
# ...

# %%
import pandas as pd
from tabulate import tabulate

# Load the car crash data
car_crash_data = pd.read_csv('Motor_Vehicle_Collisions_-_Crashes.csv')
pavement_data = pd.read_csv('Street_Pavement_Rating.csv')

# Define the column descriptions
car_crash_data_columns = [
    ('CRASH DATE', 'Date of the crash'),
    ('CRASH TIME', 'Time of the crash'),
    ('BOROUGH', 'Borough where the crash occurred'),
    ('ZIP CODE', 'Zip code where the crash occurred'),
    ('LATITUDE', 'Latitude of the crash location'),
    ('LONGITUDE', 'Longitude of the crash location'),
    ('LOCATION', 'Coordinates of the crash location (latitude, longitude)'),
    ('ON STREET NAME', 'Name of the street where the crash occurred'),
    ('CROSS STREET NAME', 'Name of the nearest cross street to the crash location'),
    ('OFF STREET NAME', 'Name of the nearest off-street to the crash location'),
    ('NUMBER OF PERSONS INJURED', 'Total number of persons injured in the crash'),
    ('NUMBER OF PERSONS KILLED', 'Total number of persons killed in the crash'),
    ('NUMBER OF PEDESTRIANS INJURED', 'Number of pedestrians injured in the crash'),
    ('NUMBER OF PEDESTRIANS KILLED', 'Number of pedestrians killed in the crash'),
    ('NUMBER OF CYCLIST INJURED', 'Number of cyclists injured in the crash'),
    ('NUMBER OF CYCLIST KILLED', 'Number of cyclists killed in the crash'),
    ('NUMBER OF MOTORIST INJURED', 'Number of motorists injured in the crash'),
    ('NUMBER OF MOTORIST KILLED', 'Number of motorists killed in the crash'),
    ('CONTRIBUTING FACTOR VEHICLE 1', 'Contributing factor for vehicle 1 involved in the crash'),
    ('CONTRIBUTING FACTOR VEHICLE 2', 'Contributing factor for vehicle 2 involved in the crash'),
    ('CONTRIBUTING FACTOR VEHICLE 3', 'Contributing factor for vehicle 3 involved in the crash'),
    ('CONTRIBUTING FACTOR VEHICLE 4', 'Contributing factor for vehicle 4 involved in the crash'),
    ('CONTRIBUTING FACTOR VEHICLE 5', 'Contributing factor for vehicle 5 involved in the crash'),
    ('COLLISION_ID', 'Unique identifier for the collision'),
    ('VEHICLE TYPE CODE 1', 'Type of vehicle 1 involved in the crash'),
    ('VEHICLE TYPE CODE 2', 'Type of vehicle 2 involved in the crash'),
    ('VEHICLE TYPE CODE 3', 'Type of vehicle 3 involved in the crash'),
    ('VEHICLE TYPE CODE 4', 'Type of vehicle 4 involved in the crash'),
    ('VEHICLE TYPE CODE 5', 'Type of vehicle 5 involved in the crash'),
    

    # Add other column descriptions here
]

pavement_data_columns = [
    ('the_geom', 'Geometry of the street segment'),
    ('SegmentID', 'Unique identifier for the street segment'),
    ('BoroughCod', 'Borough code for the street segment'),
    ('OFTCode', 'Office of Freight Transportation (OFT) code for the segment'),
    ('OnStreetNa', 'Name of the street'),
    ('FromStreet', 'Name of the street at the starting point of the segment'),
    ('ToStreetNa', 'Name of the street at the ending point of the segment'),
    ('WKT', 'Well-Known Text (WKT) representation of the street segment geometry'),
    ('ManualRati', 'Manual rating of the street pavement'),
    ('RatingLaye', 'Rating layer for the street pavement'),
    ('Inspection', 'Inspection'),
    ('Shape_STLe', 'Shape street length')

    # Add other column descriptions here
]

# Print the column names with descriptions in a table format
print("Car Crash Data Columns:")
print(tabulate(car_crash_data_columns, headers=['Column Name', 'Description'], tablefmt='grid'))

print("\nPavement Data Columns:")
print(tabulate(pavement_data_columns, headers=['Column Name', 'Description'], tablefmt='grid'))
# Out:
# Car Crash Data Columns:
# +-------------------------------+---------------------------------------------------------+
# | Column Name                   | Description                                             |
# +===============================+=========================================================+
# | CRASH DATE                    | Date of the crash                                       |
# +-------------------------------+---------------------------------------------------------+
# | CRASH TIME                    | Time of the crash                                       |
# +-------------------------------+---------------------------------------------------------+
# | BOROUGH                       | Borough where the crash occurred                        |
# +-------------------------------+---------------------------------------------------------+
# | ZIP CODE                      | Zip code where the crash occurred                       |
# ...

# %%
import pandas as pd
import numpy as np


# Drop unnecessary columns
car_crash_data = car_crash_data.drop(columns=['LOCATION','CONTRIBUTING FACTOR VEHICLE 2','CONTRIBUTING FACTOR VEHICLE 3','CONTRIBUTING FACTOR VEHICLE 4','CONTRIBUTING FACTOR VEHICLE 5' 'VEHICLE TYPE CODE 2', 'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'])
pavement_data = pavement_data.drop(columns=['BoroughCod', 'OFTCode', 'WKT', 'Shape_STLe'])

# Handle missing values
car_crash_data['LATITUDE'].fillna(car_crash_data['LATITUDE'].mean(), inplace=True)
car_crash_data['LONGITUDE'].fillna(car_crash_data['LONGITUDE'].mean(), inplace=True)

def extract_coordinates(coordinate_str):
    coordinates = coordinate_str.strip('MULTILINESTRING (()).').split(' ')[1:]
    lat = float(coordinates[0].strip(','))
    lon = float(coordinates[1])
    return lat, lon

pavement_data['LATITUDE'], pavement_data['LONGITUDE'] = zip(*pavement_data['the_geom'].apply(extract_coordinates))
pavement_data = pavement_data.drop(columns=['the_geom'])

# Save cleaned data to new CSV files
car_crash_data.to_csv('cleaned_car_crash_data.csv', index=False)
pavement_data.to_csv('cleaned_pavement_data.csv', index=False)

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cdist

def find_closest_pavement(crash_lat, crash_lon, pavement_data):
    pavement_coords = pavement_data[['LATITUDE', 'LONGITUDE']].values
    crash_coord = np.array([crash_lat, crash_lon])
    distance = cdist(crash_coord.reshape(1, -1), pavement_coords)
    min_index = np.argmin(distance)
    return pavement_data.iloc[min_index]

# Load the cleaned data
car_crash_data = pd.read_csv('cleaned_car_crash_data.csv')
pavement_data = pd.read_csv('cleaned_pavement_data.csv')

car_crash_data_with_pavement = car_crash_data.copy()
car_crash_data_with_pavement[['Pavement_LATITUDE', 'Pavement_LONGITUDE', 'Pavement_SegmentID', 'Pavement_ManualRati', 'Pavement_RatingLaye', 'Pavement_Inspection']] = car_crash_data.apply(
    lambda row: find_closest_pavement(row['LATITUDE'], row['LONGITUDE'], pavement_data)[['LATITUDE', 'LONGITUDE', 'SegmentID', 'ManualRati', 'RatingLaye', 'Inspection']], axis=1)

car_crash_data_with_pavement.to_csv('merged_car_crash_pavement_data.csv', index=False)

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

geolocator = Nominatim(user_agent="geoapiExercises")

def get_zipcode(lat, long):
    try:
        location = geolocator.reverse(f"{lat}, {long}")
        return location.raw['address'].get('postcode')
    except GeocoderTimedOut:
        return get_zipcode(lat, long)
    except Exception as e:
        print(e)
        return None

# Load the merged dataset
with open('merged_car_crash_pavement_data.csv', encoding='utf-8', errors='replace') as file:
    merged_data = pd.read_csv(file)

# Fill missing ZIP codes using latitude and longitude
merged_data['ZIP CODE'] = merged_data.apply(lambda row: get_zipcode(row['LATITUDE'], row['LONGITUDE']) if pd.isnull(row['ZIP CODE']) else row['ZIP CODE'], axis=1)

# Save the updated dataset to the same file
merged_data.to_csv('merged_car_crash_pavement_data.csv', index=False)
# Out:
# Non-successful status code 403
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.804745&lon=-73.91194&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.746296&lon=-73.97169&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
# HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=40.73876&lon=-74.00498&format=json&addressdetails=1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000253C5B3FC88>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the merged data
with open('merged_car_crash_pavement_data.csv', encoding='utf-8', errors='replace') as file:
    merged_data = pd.read_csv(file)

# Correlation matrix
corr_matrix = merged_data.corr()
plt.figure(figsize=(12, 9))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# Save the correlation matrix to a CSV file
corr_matrix.to_csv('correlation_matrix.csv')

# Print the correlation matrix as text
print(corr_matrix.to_string())
# Out:
#                                ZIP CODE  LATITUDE  LONGITUDE  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  COLLISION_ID  Pavement_LATITUDE  Pavement_LONGITUDE  Pavement_ManualRati
# ZIP CODE                       1.000000 -0.015677   0.008555                   0.041338                  0.001335                      -0.007849                     -0.000054                  -0.021878                 -0.001447                    0.053955                   0.003407      0.040825          -0.460709            0.413168             0.001114
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
merged_data = pd.read_csv('merged_car_crash_pavement_data.csv')

# Convert 'Pavement_Inspection' to datetime format
merged_data['Pavement_Inspection'] = pd.to_datetime(merged_data['Pavement_Inspection'])

# Extract the year from 'Pavement_Inspection'
merged_data['Inspection_Year'] = merged_data['Pavement_Inspection'].dt.year

# Group by 'ZIP CODE' and 'Inspection_Year' and count the number of occurrences
grouped_data = merged_data.groupby(['ZIP CODE', 'Inspection_Year']).size().reset_index(name='Count')

# Display the grouped data as text
print(grouped_data)

# Create a bar plot of the grouped data
plt.figure(figsize=(16, 6))
sns.barplot(data=grouped_data, x='ZIP CODE', y='Count', hue='Inspection_Year', palette="muted")
plt.title("Relation between ZIP CODE and Pavement Inspection Year")
plt.xticks(rotation=90)
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Number of accidents by pavement rating:
accidents_by_rating = merged_data['Pavement_RatingLaye'].value_counts()
print(accidents_by_rating)

plt.figure(figsize=(8, 6))
sns.countplot(x='Pavement_RatingLaye', data=merged_data)
plt.title('Number of Accidents by Pavement Rating')
plt.xlabel('Pavement Rating')
plt.ylabel('Number of Accidents')
plt.show()
# Out:
# GOOD    622865
# FAIR    419195
# POOR      6515
# Name: Pavement_RatingLaye, dtype: int64

# %%
#Average number of injuries by pavement rating:
# Filter out rows with 0 injuries
non_zero_injuries = merged_data[merged_data['NUMBER OF PERSONS INJURED'] != 0]
avg_injuries_by_rating = non_zero_injuries.groupby('Pavement_RatingLaye')['NUMBER OF PERSONS INJURED'].mean()
print(avg_injuries_by_rating)

plt.figure(figsize=(8, 6))
sns.barplot(x='Pavement_RatingLaye', y='NUMBER OF PERSONS INJURED', data=non_zero_injuries, estimator=lambda x: sum(x) / len(x), ci=None)
plt.title('Average Number of Injuries by Pavement Rating (Excluding Zero Injuries)')
plt.xlabel('Pavement Rating')
plt.ylabel('Average Number of Injuries')
plt.show()
# Out:
# Pavement_RatingLaye
# FAIR    1.342799
# GOOD    1.356697
# POOR    1.372230
# Name: NUMBER OF PERSONS INJURED, dtype: float64
# C:\Users\anujp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
#Average number of fatalities by pavement rating:
avg_fatalities_by_rating = merged_data.groupby('Pavement_RatingLaye')['NUMBER OF PERSONS KILLED'].mean()
print(avg_fatalities_by_rating)

plt.figure(figsize=(8, 6))
sns.barplot(x='Pavement_RatingLaye', y='NUMBER OF PERSONS KILLED', data=merged_data, estimator=lambda x: sum(x) / len(x), ci=None)
plt.title('Average Number of Fatalities by Pavement Rating')
plt.xlabel('Pavement Rating')
plt.ylabel('Average Number of Fatalities')
plt.show()
# Out:
# Pavement_RatingLaye
# FAIR    0.001362
# GOOD    0.001572
# POOR    0.000614
# Name: NUMBER OF PERSONS KILLED, dtype: float64
# C:\Users\anujp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.

# %%
#Top contributing factors for accidents:
top_contributing_factors = merged_data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)
print(top_contributing_factors)


top_contributing_factors = merged_data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_contributing_factors.values, y=top_contributing_factors.index)
plt.title('Top 10 Contributing Factors for Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('Contributing Factor')
plt.show()
# Out:
# Driver Inattention/Distraction    258545
# Unspecified                       241845
# Following Too Closely              91000
# Failure to Yield Right-of-Way      72180
# Passing or Lane Usage Improper     46499
# Backing Unsafely                   45505
# Passing Too Closely                42256
# Unsafe Lane Changing               33486
# Other Vehicular                    30205
# Turning Improperly                 24665
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64

# %%
#Accidents by borough:
accidents_by_borough = merged_data['BOROUGH'].value_counts()
print(accidents_by_borough)


plt.figure(figsize=(10, 6))
sns.countplot(y='BOROUGH', data=merged_data, order=merged_data['BOROUGH'].value_counts().index)
plt.title('Number of Accidents by Borough')
plt.xlabel('Number of Accidents')
plt.ylabel('Borough')
plt.show()
# Out:
# BROOKLYN         218584
# QUEENS           186285
# MANHATTAN        131633
# BRONX            110163
# STATEN ISLAND     25246
# Name: BOROUGH, dtype: int64

# %%
#Accidents by vehicle type:
accidents_by_vehicle_type = merged_data['VEHICLE TYPE CODE 1'].value_counts().head(10)
print(accidents_by_vehicle_type)


top_vehicle_types = merged_data['VEHICLE TYPE CODE 1'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_vehicle_types.values, y=top_vehicle_types.index)
plt.title('Top 10 Vehicle Types Involved in Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('Vehicle Type')
plt.show()
# Out:
# Sedan                                  493178
# Station Wagon/Sport Utility Vehicle    369496
# Taxi                                    43820
# Pick-up Truck                           28830
# Box Truck                               19918
# Bus                                     16871
# Bike                                    11261
# Tractor Truck Diesel                     8360
# Van                                      6980
# Motorcycle                               6116
# Name: VEHICLE TYPE CODE 1, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates

# Set the plot style
sns.set_style("whitegrid")

# Load the merged data
with open('merged_car_crash_pavement_data.csv', encoding='utf-8', errors='replace') as file:
    merged_data = pd.read_csv(file)

# Convert the CRASH DATE column to datetime and set it as the index
merged_data['CRASH DATE'] = pd.to_datetime(merged_data['CRASH DATE'])
merged_data.set_index('CRASH DATE', inplace=True)

# Filter the data to include accidents from 2012 onwards
merged_data = merged_data.loc['2012':]

# Resample the data by year and count the number of accidents
yearly_accidents = merged_data.resample('Y').size()

# Remove any data points with a year of 1970
yearly_accidents = yearly_accidents[yearly_accidents.index.year != 1970]

# Print the total number of accidents per year
print("Total number of accidents per year:")
print(yearly_accidents.to_string())

# Plot the time series
fig, ax = plt.subplots(figsize=(12, 6))
yearly_accidents.plot(ax=ax, linewidth=2.5, color='#2ca02c', marker='o', markersize=8)

# Customize the plot's appearance
ax.set_title('Total Number of Car Crashes by Year', fontsize=20, fontweight='bold')
ax.set_xlabel('Year', fontsize=16, fontweight='bold')
ax.set_ylabel('Number of Car Crashes', fontsize=16, fontweight='bold')
ax.tick_params(axis='both', which='major', labelsize=14)

# Format the x-axis
date_form = DateFormatter('%Y')
ax.xaxis.set_major_formatter(date_form)
ax.xaxis.set_major_locator(mdates.YearLocator())

# Annotate the number of accidents per year on the graph
for x, y in zip(yearly_accidents.index, yearly_accidents.values):
    ax.annotate(f'{y}', xy=(x, y), xytext=(x, y + 5000), fontsize=12, fontweight='bold', ha='center')

# Remove the right and top spines
sns.despine(right=True, top=True)

plt.show()
# Out:
# C:\Users\anujp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:19: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
# Total number of accidents per year:
# CRASH DATE
# 2012-12-31         4
# 2013-12-31         0
# 2014-12-31         0
# 2015-12-31         0
# 2016-12-31     81672
# 2017-12-31    231007
# 2018-12-31    231563
# 2019-12-31    211486
# 2020-12-31    112909
# 2021-12-31    110532
# 2022-12-31     69402
# Freq: A-DEC

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the merged data
merged_data = pd.read_csv('merged_car_crash_pavement_data.csv')

# Convert the CRASH DATE and CRASH TIME columns to datetime objects
merged_data['CRASH DATE'] = pd.to_datetime(merged_data['CRASH DATE'])
merged_data['CRASH TIME'] = pd.to_datetime(merged_data['CRASH TIME'], format='%H:%M')

# Create columns for the day of the week and hour of the day
merged_data['DAY OF WEEK'] = merged_data['CRASH DATE'].dt.dayofweek
merged_data['HOUR OF DAY'] = merged_data['CRASH TIME'].dt.hour

# Create a pivot table to count the number of accidents by day of week and hour of day
accidents_pivot = merged_data.pivot_table(index='DAY OF WEEK', columns='HOUR OF DAY', values='CRASH TIME', aggfunc='count')

# Plot the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(accidents_pivot, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('Number of Car Crashes by Day of Week and Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Day of Week')

# Customize y-axis labels
day_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plt.yticks(range(7), day_labels, rotation=0)

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the merged data
# Load the merged data
with open('merged_car_crash_pavement_data.csv', encoding='utf-8', errors='replace') as file:
    merged_data = pd.read_csv(file)

# Convert the CRASH DATE and CRASH TIME columns to datetime objects
merged_data['CRASH DATE'] = pd.to_datetime(merged_data['CRASH DATE'])
merged_data['CRASH TIME'] = pd.to_datetime(merged_data['CRASH TIME'], format='%H:%M')

# Create columns for the day of the week and hour of the day
merged_data['DAY OF WEEK'] = merged_data['CRASH DATE'].dt.dayofweek
merged_data['HOUR OF DAY'] = merged_data['CRASH TIME'].dt.hour

# Create a pivot table to count the number of accidents by day of week and hour of day
accidents_pivot = merged_data.pivot_table(index='DAY OF WEEK', columns='HOUR OF DAY', values='CRASH TIME', aggfunc='count')

# Print the number of accidents by day of week and hour of day
day_labels = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

print("Number of Car Crashes by Day of Week and Hour of Day:")
for i, day in enumerate(day_labels):
    print("\n{}:".format(day))
    for hour in range(24):
        print("Hour {}: {} accidents".format(hour, int(accidents_pivot.loc[i, hour])))
# Out:
# Number of Car Crashes by Day of Week and Hour of Day:
#
# Monday:
# Hour 0: 5287 accidents
# Hour 1: 2197 accidents
# Hour 2: 1552 accidents
# Hour 3: 1286 accidents
# Hour 4: 1555 accidents
# Hour 5: 2156 accidents
# Hour 6: 4043 accidents
# Hour 7: 5907 accidents
# Hour 8: 9608 accidents
# Hour 9: 8816 accidents
# Hour 10: 7862 accidents
# Hour 11: 8110 accidents
# Hour 12: 8226 accidents
# Hour 13: 8588 accidents
# Hour 14: 9751 accidents
# Hour 15: 9565 accidents
# Hour 16: 10972 accidents
# Hour 17: 10723 accidents
# Hour 18: 8937 accidents
# Hour 19: 7097 accidents
# Hour 20: 5487 accidents
# Hour 21: 4533 accidents
# Hour 22: 3924 accidents
# Hour 23: 3227 accidents
#
# Tuesday:
# Hour 0: 4621 accidents
# Hour 1: 1548 accidents
# Hour 2: 1116 accidents
# Hour 3: 974 accidents
# Hour 4: 1052 accidents
# Hour 5: 1902 accidents
# Hour 6: 3920 accidents
# Hour 7: 6000 accidents
# Hour 8: 10297 accidents
# Hour 9: 9470 accidents
# Hour 10: 8202 accidents
# Hour 11: 8253 accidents
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the merged data
with open('merged_car_crash_pavement_data.csv', encoding='utf-8', errors='replace') as file:
    merged_data = pd.read_csv(file)

# Group by borough and calculate the mean pavement quality
borough_pavement_quality = merged_data.groupby('BOROUGH')['Pavement_ManualRati'].mean()

# Print pavement quality by borough in text format
print("Pavement Quality by Borough:")
for borough, quality in borough_pavement_quality.items():
    print(f"{borough}: {quality:.2f}")

# Plot pavement quality by borough
plt.figure(figsize=(10, 6))
sns.barplot(x=borough_pavement_quality.index, y=borough_pavement_quality.values)
plt.title('Average Pavement Quality by Borough')
plt.xlabel('Borough')
plt.ylabel('Average Pavement Quality')
plt.show()
# Out:
# Pavement Quality by Borough:
# BRONX: 7.35
# BROOKLYN: 7.67
# MANHATTAN: 7.43
# QUEENS: 7.22
# STATEN ISLAND: 7.44

# %%
import pandas as pd

# Load the merged data
with open('merged_car_crash_pavement_data.csv', encoding='utf-8', errors='replace') as file:
    merged_data = pd.read_csv(file)

# Group the data by street name and borough and aggregate by the count of car crashes for each pavement rating
street_borough_crash_count = merged_data.groupby(['Street Name', 'Borough', 'Pavement_RatingLaye'])['CRASH DATE'].count().reset_index(name='CrashCount')

# Pivot the data to get the pavement rating as columns
pivoted_data = street_borough_crash_count.pivot(index=['Street Name', 'Borough'], columns='Pavement_RatingLaye', values='CrashCount').fillna(0).reset_index()

# Calculate the total crash count for each street and borough
pivoted_data['TotalCrashCount'] = pivoted_data.iloc[:, 2:].sum(axis=1)

# Sort the data by total crash count in descending order and select the top 5 streets
top_5_streets = pivoted_data.sort_values(by='TotalCrashCount', ascending=False).head(5)

# Select only the necessary columns
top_5_streets_table = top_5_streets[['Street Name', 'Borough', 'Poor', 'Fair', 'Good', 'TotalCrashCount']]

# Rename the columns for better readability
top_5_streets_table.columns = ['Street Name', 'Borough', 'Poor Pavement', 'Fair Pavement', 'Good Pavement', 'Total Crash Count']

# Print the top 5 streets table
print(top_5_streets_table.to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12344\1229107089.py in <module>
#       6
#       7 # Group the data by street name and borough and aggregate by the count of car crashes for each pavement rating
# ----> 8 street_borough_crash_count = merged_data.groupby(['Street Name', 'Borough', 'Pavement_RatingLaye'])['CRASH DATE'].count().reset_index(name='CrashCount')
#       9
#      10 # Pivot the data to get the pavement rating as columns
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
# ...
